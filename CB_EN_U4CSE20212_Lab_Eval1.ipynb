# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Set 2

# %%
#Q1
import pandas as pd

a = pd.read_csv("/content/drive/MyDrive/Data Science Dataset/IoTBotNetDataset.csv")
a
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0            1.0  1.528089e+09     e          1.0   tcp           1.0
# 1            2.0  1.528089e+09     e          1.0   arp           2.0
# 2            3.0  1.528089e+09     e          1.0   UDP           1.0
# 3            4.0  1.528089e+09     i          1.0   tcp           1.0
# 4            5.0  1.528089e+09     e          1.0   UDP           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998548  998549.0  1.528085e+09     e          1.0   udp           3.0
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# ...

# %%
#Q2
b = a.drop(columns=["bytes","ltime","Pkts_P_State_P_Protocol_P_SrcIP","flgs_number","proto_number","saddr","sport","daddr","dport","state","state_number","seq","dur","mean","stddev","sum","min","max","spkts","dpkts","rate","srate","drate","TnBPSrcIP","TnBPDstIP","TnP_PSrcIP","TnP_PDstIP","TnP_PerProto","TnP_Per_Dport","AR_P_Proto_P_SrcIP","AR_P_Proto_P_DstIP","N_IN_Conn_P_DstIP","N_IN_Conn_P_SrcIP","AR_P_Proto_P_Sport","AR_P_Proto_P_Dport","attack","category"])
b
# Out:
#          pkSeqID         stime flags proto  pkts  sbytes  dbytes  \
# 0            1.0  1.528089e+09     e   tcp   8.0   650.0  1330.0
# 1            2.0  1.528089e+09     e   arp   2.0    60.0    60.0
# 2            3.0  1.528089e+09     e   UDP   8.0   796.0  1330.0
# 3            4.0  1.528089e+09     i   tcp   8.0   694.0  1330.0
# 4            5.0  1.528089e+09     e   UDP   8.0   989.0  1330.0
# ...          ...           ...   ...   ...   ...     ...     ...
# 998548  998549.0  1.528085e+09     e   udp   7.0   420.0     0.0
# 998549  998550.0  1.528085e+09     e   udp   7.0   420.0     0.0
# 998550  998551.0  1.528085e+09     e   udp   7.0   420.0     0.0
# 998551  998552.0  1.528085e+09     e   udp   7.0   420.0     0.0
# 998552  998553.0  1.528085e+09     e   udp   7.0   420.0     0.0
#
#         Pkts_P_State_P_Protocol_P_DestIP subcategory
# 0                                  770.0        HTTP
# 1                                    2.0        HTTP
# ...

# %%
#Q3
b.fillna("ffill")
c = b.loc[(b!=0).all(axis=1)]
c
# Out:
#          pkSeqID         stime flags proto  pkts  sbytes  dbytes  \
# 0            1.0  1.528089e+09     e   tcp   8.0   650.0  1330.0
# 1            2.0  1.528089e+09     e   arp   2.0    60.0    60.0
# 2            3.0  1.528089e+09     e   UDP   8.0   796.0  1330.0
# 3            4.0  1.528089e+09     i   tcp   8.0   694.0  1330.0
# 4            5.0  1.528089e+09     e   UDP   8.0   989.0  1330.0
# ...          ...           ...   ...   ...   ...     ...     ...
# 840287  840288.0  1.528085e+09     e   arp   8.0   240.0   240.0
# 840544  840545.0  1.528085e+09     e   arp   2.0    60.0    60.0
# 840672  840673.0  1.528085e+09     e   arp   2.0    60.0    60.0
# 843637  843638.0  1.528085e+09     e   arp   2.0    60.0    60.0
# 843999  844000.0  1.528085e+09     e   arp   7.0   300.0   120.0
#
#         Pkts_P_State_P_Protocol_P_DestIP subcategory
# 0                                  770.0        HTTP
# 1                                    2.0        HTTP
# ...

# %%
#Q4
import matplotlib.pyplot as plt

plt.subplot(1,2,1)
plt.boxplot(c[["Pkts_P_State_P_Protocol_P_DestIP"]].head(100))
plt.subplot(1,2,2)
plt.boxplot(c[["sbytes"]].head(100))
plt.show()

# %%
#Q5
import seaborn as sns

sns.pairplot(c[["sbytes"]],c[["dbytes"]])

# %%
#Q6
c.describe()
# Out:
#              pkSeqID         stime           pkts         sbytes  \
# count  331288.000000  3.312880e+05  331288.000000  331288.000000
# mean   327860.572783  1.528081e+09       5.541834     549.252913
# std    172992.172493  4.806456e+02       1.672559     219.241029
# min         1.000000  1.528081e+09       2.000000      60.000000
# 25%    183844.750000  1.528081e+09       5.000000     428.000000
# 50%    333284.500000  1.528081e+09       6.000000     616.000000
# 75%    488497.250000  1.528081e+09       6.000000     770.000000
# max    844000.000000  1.528089e+09      67.000000    5872.000000
#
#               dbytes  Pkts_P_State_P_Protocol_P_DestIP
# count  331288.000000                     331288.000000
# mean       95.047448                        331.883627
# std        72.193061                        160.263011
# min        60.000000                          2.000000
# 25%        60.000000                        233.000000
# ...

# %%
#Q7
c.head(3)
# Out:
#    pkSeqID         stime flags proto  pkts  sbytes  dbytes  \
# 0      1.0  1.528089e+09     e   tcp   8.0   650.0  1330.0
# 1      2.0  1.528089e+09     e   arp   2.0    60.0    60.0
# 2      3.0  1.528089e+09     e   UDP   8.0   796.0  1330.0
#
#    Pkts_P_State_P_Protocol_P_DestIP subcategory
# 0                             770.0        HTTP
# 1                               2.0        HTTP
# 2                             770.0        HTTP

# %%
#Q8
c.tail(4)
# Out:
#          pkSeqID         stime flags proto  pkts  sbytes  dbytes  \
# 840544  840545.0  1.528085e+09     e   arp   2.0    60.0    60.0
# 840672  840673.0  1.528085e+09     e   arp   2.0    60.0    60.0
# 843637  843638.0  1.528085e+09     e   arp   2.0    60.0    60.0
# 843999  844000.0  1.528085e+09     e   arp   7.0   300.0   120.0
#
#         Pkts_P_State_P_Protocol_P_DestIP subcategory
# 840544                               2.0         UDP
# 840672                               2.0         UDP
# 843637                               2.0         UDP
# 843999                               7.0         UDP

# %%
#Q9
c.loc[(c[["subcategory"]]=="UDP").all(axis=1)].head(1)
# Out:
#          pkSeqID         stime flags proto  pkts  sbytes  dbytes  \
# 618665  618666.0  1.528085e+09     e   arp  18.0   540.0   540.0
#
#         Pkts_P_State_P_Protocol_P_DestIP subcategory
# 618665                              18.0         UDP

# %%
#Q10
len(c)
# Out:
# 333544

# %%
#Q11
c.iloc[1:2,1:6]
# Out:
#           stime flags proto  pkts  sbytes
# 1  1.528089e+09     e   arp   2.0    60.0

# %%
#Q12
len(c.loc[(c[["flags"]]=="i").all(axis=1)])
# Out:
# 30

# %%
#Q13
group1 = c.loc[(c[["pkts"]]<=10).all(axis=1)]
group1
# Out:
#          pkSeqID         stime flags proto  pkts  sbytes  dbytes  \
# 144        145.0  1.528089e+09   e s   tcp  12.0  2287.0  1330.0
# 276        277.0  1.528089e+09   e s   tcp  14.0  3723.0   700.0
# 277        278.0  1.528089e+09   e s   UDP  11.0  2504.0   700.0
# 278        279.0  1.528089e+09   e s   UDP  12.0  2590.0   700.0
# 283        284.0  1.528089e+09   e s   tcp  11.0  2008.0   700.0
# ...          ...           ...   ...   ...   ...     ...     ...
# 613499  613500.0  1.528081e+09   e s   tcp  12.0  1104.0   180.0
# 613507  613508.0  1.528081e+09   e s   tcp  12.0  1104.0   180.0
# 613528  613529.0  1.528081e+09   e s   tcp  12.0  1104.0   180.0
# 616536  616537.0  1.528081e+09     e   arp  17.0   840.0   180.0
# 618665  618666.0  1.528085e+09     e   arp  18.0   540.0   540.0
#
#         Pkts_P_State_P_Protocol_P_DestIP subcategory
# 144                                375.0        HTTP
# 276                                754.0        HTTP
# ...

# %%
group2 = c.loc[(c[["pkts"]]>10).all(axis=1)]
group2
# Out:
#          pkSeqID         stime flags proto  pkts  sbytes  dbytes  \
# 144        145.0  1.528089e+09   e s   tcp  12.0  2287.0  1330.0
# 276        277.0  1.528089e+09   e s   tcp  14.0  3723.0   700.0
# 277        278.0  1.528089e+09   e s   UDP  11.0  2504.0   700.0
# 278        279.0  1.528089e+09   e s   UDP  12.0  2590.0   700.0
# 283        284.0  1.528089e+09   e s   tcp  11.0  2008.0   700.0
# ...          ...           ...   ...   ...   ...     ...     ...
# 613499  613500.0  1.528081e+09   e s   tcp  12.0  1104.0   180.0
# 613507  613508.0  1.528081e+09   e s   tcp  12.0  1104.0   180.0
# 613528  613529.0  1.528081e+09   e s   tcp  12.0  1104.0   180.0
# 616536  616537.0  1.528081e+09     e   arp  17.0   840.0   180.0
# 618665  618666.0  1.528085e+09     e   arp  18.0   540.0   540.0
#
#         Pkts_P_State_P_Protocol_P_DestIP subcategory
# 144                                375.0        HTTP
# 276                                754.0        HTTP
# ...

# %%
#Q13(a),(b),(c)
print("Mean",c[["pkts"]].mean())
print("Deviation",(c[["pkts"]].var())**0.5)
print("Mean",c[["sbytes"]].mean())
print("Deviation",(c[["sbytes"]].var())**0.5)
print("Mean",c[["dbytes"]].mean())
print("Deviation",(c[["dbytes"]].var())**0.5)
# Out:
# Mean pkts    5.541834
# dtype: float64
# Deviation pkts    1.672559
# dtype: float64
# Mean sbytes    549.252913
# dtype: float64
# Deviation sbytes    219.241029
# dtype: float64
# Mean dbytes    95.047448
# dtype: float64
# Deviation dbytes    72.193061
# dtype: float64

# %%
#Q14
c.groupby("subcategory").mean()[["Pkts_P_State_P_Protocol_P_DestIP"]].head(2)
# Out:
#              Pkts_P_State_P_Protocol_P_DestIP
# subcategory
# HTTP                               746.097643
# TCP                                330.026416

# %%
#Q15
import matplotlib.pyplot as plt

plt.hist(c[["stime"]].head(100))
plt.show()
